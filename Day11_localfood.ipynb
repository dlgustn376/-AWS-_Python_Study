# %% [markdown]
# ### 전국로컬푸드인증정보표준데이터
#
# url: https://www.data.go.kr/data/15025455/standard.do
#
# * 품목 top 10(품목별 카운트)
#     - 다중품목( + 또는 , 로 연결)은 각각 분리
#     - 이외 단일품목으로 취급
#     - 나머지는 알아서 ex) 파(실파+대파) -> 파 또는 [실파,대파]로 취급
# * 주소공란 : 옆칸 조회해서 메꾸기
# * dictionary 작성 :{군단위 지역명: 품목명}
# * dictionary 작성 :{품목: 군단위 지역명}
#
# * jupyter note 업로드: 이름_로컬푸드.ipynb
#     192.168.2.101:8000/upload

# %%
import numpy as np
import math

def my_split(s):
    block_start = False
    start_index = 0
    ret_list=[]
    for i, c in enumerate(s):
        if block_start==False:
            if c==',':
                ret_list.append(s[start_index:i])
                start_index=i+1
            elif c=='"':
                block_start=True
                start_index = i
        else:
            if c=='"':
                block_start=False
    if s[-1]!=',':
        ret_list.append(s[start_index:])
    return ret_list

def split_len(data_list):
    len_list=[]
    for e in data_list:
        len_list.append(len(e))
    print(set(len_list))
    if(len(set(len_list))):
        for i in set(len_list):
            print(i, len_list.count(i))
            
raw_data = []
with open('전국로컬푸드인증정보표준데이터.csv') as f:
    for line in f:
        raw_data.append(my_split(line[:-1]))
print(raw_data[:3])
split_len(raw_data)
# Out:
# [['로컬푸드인증번호', '인증유효시작일자', '인증유효종료일자', '인증취소일자', '사업장도로명주소', '사업장지번주소', '생산지도로명주소', '생산지지번주소', '품목명', '재배면적', '재배규모', '인증부여일자', '사업자명', '사업자등록번호', '전화번호', '관리기관명', '데이터기준일자', '제공기관코드', '제공기관명'], ['HYG-162', '2021-09-01', '2031-09-01', '', '경상남도 함양군 수동면 산업단지길 209+경상남도 함양군 수동면 우명하교로 174', '', '경상남도 함양군 병곡면 다볕길 94', '', '칡청+달맞이꽃씨유', '', '122', '2021-09-01', '청운당농산', '', '070-7779-2122', '경상남도 함양군청', '2022-11-23', '5460000', '경상남도 함양군'], ['HYG-163', '2021-09-01', '2031-09-01', '', '경상남도 함양군 수동면 산업단지길 209+경상남도 함양군 수동면 우명하교로 174', '', '경상남도 함양군 수동면 사근산성길 35-4', '', '굼벵이환', '', '123', '2021-09-01', '굼찬농장', '', '070-7779-2122', '경상남도 함양군청', '2022-11-23', '5460000', '경상남도 함양군']]
# {19}
# 19 7794

# %%
for e in enumerate(raw_data[0]):
    print(e)
# Out:
# (0, '로컬푸드인증번호')
# (1, '인증유효시작일자')
# (2, '인증유효종료일자')
# (3, '인증취소일자')
# (4, '사업장도로명주소')
# (5, '사업장지번주소')
# (6, '생산지도로명주소')
# (7, '생산지지번주소')
# (8, '품목명')
# (9, '재배면적')
# (10, '재배규모')
# (11, '인증부여일자')
# (12, '사업자명')
# (13, '사업자등록번호')
# (14, '전화번호')
# (15, '관리기관명')
# (16, '데이터기준일자')
# (17, '제공기관코드')
# (18, '제공기관명')

# %%
np_data = np.array(raw_data)
#print(np_data)
np_data = np_data[:, 4:9]
print(np_data.shape)
print(np_data[0])
# Out:
# (7794, 5)
# ['사업장도로명주소' '사업장지번주소' '생산지도로명주소' '생산지지번주소' '품목명']

# %%
def process_product_names(s):
    r =[]
    remove_after=['(','외','-','등','_','"','C반)']
    split_at = ['+',',']
    for c in remove_after:
        if c in s:
            s = s[:s.index(c)]
            
    for c in split_at:
        if c in s:
            r = r + s.split(c)
    if len(r) == 0:
        r.append(s)
    
    return r


sample1 = 'product1+product2'
sample2 = 'product1,product2'
sample3 = 'product(1+2)'
sample4 = 'product외 abc'
sample5 = 'product-순순순'
sample6 = 'product등'



# process_product_names(sample1);  #['product1', 'product2']

assert process_product_names(sample1) == ['product1', 'product2']
assert process_product_names(sample2) == ['product1', 'product2']
assert process_product_names(sample3) == ['product']
assert process_product_names(sample4) == ['product']
assert process_product_names(sample5) == ['product']
assert process_product_names(sample6) == ['product']

# %%
area_name_list=[]
product_list=[]
all_data=[]
for sample in np_data:
    area_name=''
    for i in sample[:-1]:
        i = i.strip(' "')
        if len(i)>0:
            area_name = ' '.join(i.split()[:2])
#             area_name_list.append(area_name)
            break
#     product_list.append(process_product_names(sample[-1]))
    for p in process_product_names(sample[-1]):
        all_data.append([area_name, p])
    
print(area_name_list[:3], len(area_name_list))
print(product_list[:3], len(product_list))
print(all_data)
# Out:
# [] 0
# [] 0
# [['사업장도로명주소', '품목명'], ['경상남도 함양군', '칡청'], ['경상남도 함양군', '달맞이꽃씨유'], ['경상남도 함양군', '굼벵이환'], ['경상남도 함양군', '메론'], ['경상남도 함양군', '차요태'], ['경상남도 함양군', '열매마'], ['경상남도 함양군', '포도'], ['경상남도 함양군', '꿀'], ['경상남도 함양군', '포도'], ['경상남도 함양군', '사과'], ['경상남도 함양군', '샤인머스켓'], ['경상남도 함양군', '미숫가루'], ['경상남도 함양군', '밀가루'], ['경상남도 함양군', '쌀'], ['경상남도 함양군', '사과'], ['경상남도 함양군', '알밤'], ['경상남도 함양군', '한라봉'], ['경상남도 함양군', '레드향'], ['경상남도 함양군', '천혜향'], ['경상남도 함양군', '사과'], ['경상남도 함양군', '서복태'], ['경상남도 함양군', '함양애주'], ['경상남도 함양군', '지리산애주'], ['경상남도 함양군', '키고리'], ['경상남도 함양군', '스카프'], ['경상남도 함양군', '가방'], ['경상남도 함양군', '두건'], ['경상남도 함양군', '로메인 상추'], ['경상남도 함양군', '더덕주'], ['경상남도 함양군', '블루베리'], ['경상남도 함양군', '호두'], ['경상남도 함양군', '새싹인삼'], ['경상남도 함양군', '유정란'], ['경상남도 함양군', '한과'], ['경상남도 함양군', '도라지'], ['경상남도 함양군', '곶감'], ['경상남도 함양군', '감말랭이'], ['경상남도 함양군', '딸기'], ['경상남도 함양군', '고로쇠 수액'], ['경상남도 함양군', '지리산도라지와돌배'], ['경상남도 함양군', '곶감'], ['경상남도 함양군', '말랭이'], ['경상남도 함양군', '사과'], ['경상남도 함양군', '딸기'], ['경상남도 함양군', '복수박'], ['경상남도 함양군', '두릅'], ['경상남도 함양군', '고사리'], ['경상남도 함양군', '취나물'], ['경상남도 함양군', '누른호박'], ['경상남도 함양군', '배'], ['경상남도 함양군', '즙류'], ['경상남도 함양군', 'ABC주스'], ['경상남도 함양군', '우슬진액'], ['경상남도 함양군', '꿀류'], ['경상남도 함양군', '차류'], ['경상남도 함양군', '미나리'], ['경상남도 함양군', '두릅'], ['경상남도 함양군', '취나물'], ['경상남도 함양군', '머위즙'], ['경상남도 함양군', '삼백초즙'], ['경상남도 함양군', '블루베리'], ['경상남도 함양군', '신령호두'], ['경상남도 함양군', '부각류'], ['경상남도 함양군', '블루베리'], ['경상남도 함양군', '가지'], ['경상남도 함양군', '애호박'], ['경상남도 함양군', '사과'], ['경상남도 함양군', '차류'], ['경상남도 함양군', '아스파라거스'], ['경상남도 함양군', '담솔'], ['경상남도 함양군', '복분자'], ['경상남도 함양군', '솔송주'], ['경상남도 함양군', '고구마'], ['경상남도 함양군', '사과'], ['경상남도 함양군', '도마'], ['경상남도 함양군', '주걱'], ['경상남도 함양군', '약초류'], ['경상남도 함양군', '유기농계란'], ['경상남도 함양군', '엉겅퀴'], ['경상남도 함양군', '오가피'], ['경상남도 함양군', '죽염류'], ['경상남도 함양군', '된장'], ['경상남도 함양군', '치약'], ['경상남도 함양군', '국화분재'], ['경상남도 함양군', '표고버섯'], ['경상남도 함양군', '도라지'], ['경상남도 함양군', '부각류'], ['경기도 화성시', '옥수수'], ['경상남도 함양군', '그린하미과'], ['경상남도 함양군', '컬리플라워'], ['경상남도 함양군', '생강청'], ['경상남도 함양군', '산골편강'], ['경상남도 함양군', '도라비배청'], ['경상남도 함양군', '보리새싹'], ['경상남도 함양군', '레몬머틀'], ['경상남도 함양군', '배'], ['경상남도 함양군', '고구마'], ['경상남도 함양군', '오란다'], ['경상남도 함양군', '조청산자'], ['경상남도 함양군', '김부각'], ['경상남도 함양군', '강정류'], ['경상남도 함양군', '꿀류'], ['경상남도 함양군', '곶감'], ['경상남도 함양군', '대파'], ['경상남도 함양군', '양상추'], ['경상남도 함양군', '곶감'], ['경상남도 함양군', '사과'], ['경상남도 함양군', '사과즙'], ['경상남도 함양군', '오미자청'], ['경상남도 함양군', '도라지배즙'], ['경상남도 함양군', '고구마'], ['경상남도 함양군', '무말랭이'], ['경상남도 함양군', '시래기'], ['경상남도 함양군', '사과'], ['경상남도 함양군', '사과즙'], ['경상남도 함양군', '반쯤깐밤'], ['경상남도 함양군', '산삼캔디'], ['경상남도 함양군', '지리산명월초 티백차'], ['경상남도 함양군', '표고버섯'], ['경상남도 함양군', '우산고로쇠 수액'], ['경상남도 함양군', '본래족발스페셜세트'], ['경상남도 함양군', '이불'], ['경상남도 함양군', '베개'], ['경상남도 함양군', '목화솜'], ['경상남도 함양군', '꾸찌봉차'], ['경상남도 함양군', '꾸지뽕진액'], ['경상남도 함양군', '오미자즙'], ['경상남도 함양군', '양파즙'], ['경상남도 함양군', '매실원액'], ['경상남도 함양군', '개복숭아원액'], ['경상남도 함양군', '솔순원액'], ['경상남도 함양군', '고로쇠 수액'], ['경상남도 함양군', '달걀'], ['경상남도 함양군', '꿀'], ['경상남도 함양군', '화분'], ['경상남도 함양군', '아스파라거스'], ['경상남도 함양군', '꿀류'], ['경상남도 함양군', '고구마'], ['경상남도 함양군', '산삼캔디'], ['경상남도 함양군', '산삼젤리'], ['경상남도 함양군', '곡물강정'], ['경상남도 함양군', '산삼견과정'], ['경상남도 함양군', '오미자랑'], ['경상남도 함양군', '고추부각'], ['경상남도 함양군', '김부각'], ['경상남도 함양군', '고추장'], ['경상남도 함양군', '된장'], ['경상남도 함양군', '간장'], ['경상남도 함양군', '사과'], ['경상남도 함양군', '국수'], ['경상남도 함양군', '마스크팩'], ['경상남도 함양군', '샴푸'], ['경상남도 함양군', '산삼주'], ['경상남도 함양군', '무말랭이'], ['경상남도 함양군', '아주까리잎'], ['경상남도 함양군', '토마토'], ['경상남도 함양군', '열매마'], ['경상남도 함양군', '지리산 배도라지 생강청'], ['경상남도 함양군', '백봉령'], ['경상남도 함양군', '도라지'], ['경상남도 함양군', '산머루즙골드'], ['경상남도 함양군', '블루베리진액'], ['경상남도 함양군', '상황버섯진액'], ['경상남도 함양군', '하늘과맞닿은 사과즙 도라지배즙'], ['경상남도 함양군', '냉동산딸기'], ['경상남도 함양군', '적양파'], ['경상남도 함양군', '양파'], ['경상남도 함양군', '감자'], ['경상남도 함양군', '수박'], ['경상남도 함양군', '지리산 꾸찌봉잎차'], ['경기도 화성시', '산딸기'], ['경기도 화성시', ''], ['경기도 화성시', ''], ['경기도 화성시', ''], ['경기도 화성시', ''], ['경기도 화성시', ''], ['경기도 화성시', '포도'], ['경기도 화성시', '블루베리'], ['경기도 화성시', '블루베리'], ['경기도 화성시', '복숭아'], ['경기도 화성시', '토종빨강강낭콩'], ['경기도 화성시', '고추'], ['경기도 화성시', '새송이'], ['경기도 화성시', '감자'], ['경기도 화성시', '완두'], ['경기도 화성시', ''], ['경기도 화성시', '당근'], ['경기도  ...

# %%
# print(all_data[:10])
fw_area_name = []
fw_products = []
for v in all_data:
    if v[0] in fw_area_name:
        i = fw_area_name.index(v[0])
        fw_products[i].append(v[1])
    else:
        fw_area_name.append(v[0])
        fw_products.append([v[1]])
        
# print(fw_area_name[:3], len(fw_area_name))
# print(fw_products[:3], len(fw_products))
fw_dict = dict(zip(fw_area_name, fw_products))
# print(fw_dict)
print(fw_dict['경상남도 함양군'])
print(len(fw_dict['경상남도 함양군']))
# Out:
# ['칡청', '달맞이꽃씨유', '굼벵이환', '메론', '차요태', '열매마', '포도', '꿀', '포도', '사과', '샤인머스켓', '미숫가루', '밀가루', '쌀', '사과', '알밤', '한라봉', '레드향', '천혜향', '사과', '서복태', '함양애주', '지리산애주', '키고리', '스카프', '가방', '두건', '로메인 상추', '더덕주', '블루베리', '호두', '새싹인삼', '유정란', '한과', '도라지', '곶감', '감말랭이', '딸기', '고로쇠 수액', '지리산도라지와돌배', '곶감', '말랭이', '사과', '딸기', '복수박', '두릅', '고사리', '취나물', '누른호박', '배', '즙류', 'ABC주스', '우슬진액', '꿀류', '차류', '미나리', '두릅', '취나물', '머위즙', '삼백초즙', '블루베리', '신령호두', '부각류', '블루베리', '가지', '애호박', '사과', '차류', '아스파라거스', '담솔', '복분자', '솔송주', '고구마', '사과', '도마', '주걱', '약초류', '유기농계란', '엉겅퀴', '오가피', '죽염류', '된장', '치약', '국화분재', '표고버섯', '도라지', '부각류', '그린하미과', '컬리플라워', '생강청', '산골편강', '도라비배청', '보리새싹', '레몬머틀', '배', '고구마', '오란다', '조청산자', '김부각', '강정류', '꿀류', '곶감', '대파', '양상추', '곶감', '사과', '사과즙', '오미자청', '도라지배즙', '고구마', '무말랭이', '시래기', '사과', '사과즙', '반쯤깐밤', '산삼캔디', '지리산명월초 티백차', '표고버섯', '우산고로쇠 수액', '본래족발스페셜세트', '이불', '베개', '목화솜', '꾸찌봉차', '꾸지뽕진액', '오미자즙', '양파즙', '매실원액', '개복숭아원액', '솔순원액', '고로쇠 수액', '달걀', '꿀', '화분', '아스파라거스', '꿀류', '고구마', '산삼캔디', '산삼젤리', '곡물강정', '산삼견과정', '오미자랑', '고추부각', '김부각', '고추장', '된장', '간장', '사과', '국수', '마스크팩', '샴푸', '산삼주', '무말랭이', '아주까리잎', '토마토', '열매마', '지리산 배도라지 생강청', '백봉령', '도라지', '산머루즙골드', '블루베리진액', '상황버섯진액', '하늘과맞닿은 사과즙 도라지배즙', '냉동산딸기', '적양파', '양파', '감자', '수박', '지리산 꾸찌봉잎차', '애플수박', '한방향낭', '국수호박', '꿀류', '꿀류', '호두', '포도', '포도', '장아찌류', '꿀류', '꿀류', '연꽃에센스 미스트', '마스크팩세트', '족발', '쌈장', '새우젓', '블루베리', '아로니아', '생강청', '배도라지청', '포도', '고추', '곶감', '감말랭이', '사과', '즙류', '다류', '대추', '아로니아', '단감', '대봉감', '즙류', '잼류', '딸기', '족발세트', '산양삼농축액', '김부각', '약초류', '나물류', '죽염관련제품', '냉면', '삼계탕', '도가니탕', '우족탕', '노루궁뎅이', '버섯', '연잎밥', '연근차', '연잎차', '연잎가루', '연근가루', '마스크팩', '호두', '고사리', '국수', '고로쇠 수액', '양파', '감자', '들기름', '참기름', '복수박', '수박', '지리산흑돼지 불고기용', '지리산흑돼지 찌개용 500G', '토마토', '복수박', '나물류', '양파', '오미자', '오미자즙', '꿀', '블루베리', '딸기', '복수박', '토마토', '된장', '고추장', '석이버섯', '표고버섯', '양배추', '미니배추', '브로콜리', '콜리플라워', '요구르트', '치즈', '당귀', '황기', '오미자', '오미자즙', '헛개나무', '약초류', '흑돼지', '떡갈비', '아피오스', '산양삼꾸지뽕', '배', '배즙', '사과', '꿀', '블루베리', '된장', '고추장', '감식초', '뽕잎환', '산머루즙', '산머루팩', '산머루와인', '곶감', '시래기', '산양삼 음료', '산양삼', '여주', '돼지감자', '호두', '감', '감말랭이', '장아찌류', '생강차', '사과', '말랭이', '머뮈잎', '무말랭이', '옻순', '취나물', '토란대', '곶감', '다류', '말랭이', '액상차', '고추', '나물', '오디', '꾸지뽕엑기스', '곶감', '아로니아', '호두', '수박', '흑돼지', '한우사골곰탕', '곡류', '복숭아', '곶감', '감말랭이', '고구마', '옻나무', '환류', '청류', '다류', '사과', '흑돼지소시지', '배', '배즙', '오미자즙', '양파즙', '아로니아즙', '표고버섯', '대봉', '무말랭이', '머위잎', '토란대', '무유황', '감말랭이', '야콘', '고구마형 과자', '왕소라형과자', '소프트매실캔디', '매실젤리', '생강젤리', '석이버섯', '콜프프레스 프리미엄 생들께오일5종']
# 339

# %%
re_fw_area_name = []
re_fw_products = []
for v in all_data:
    if v[1] in re_fw_products:
        i = re_fw_products.index(v[1])
        re_fw_area_name[i].append(v[0])
    else:
        re_fw_products.append(v[1])
        re_fw_area_name.append([v[0]])
        
        
rev_dict = dict(zip(re_fw_products,re_fw_area_name))
print(len(rev_dict))
print(rev_dict['사과'], len(rev_dict['사과']))
# Out:
# 1155
# ['경상남도 함양군', '경상남도 함양군', '경상남도 함양군', '경상남도 함양군', '경상남도 함양군', '경상남도 함양군', '경상남도 함양군', '경상남도 함양군', '경상남도 함양군', '경기도 화성시', '경기도 화성시', '충청남도 서산시', '충청남도 당진시', '충청남도 당진시', '충청남도 당진시', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '영월군 중동면', '영월군 영월읍', '영월군 주천면', '영월군 북면', '영월군 남면', '영월군 영월읍', '강원도 영월군', '경기도 화성시', '경기도 화성시', '강원도 영월군', '강원도 영월군', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '충청북도 옥천군', '충청북도 옥천군', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '전라북도 완주군', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '전라남도 순천시', '전라남도 순천시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '강원도 원주시', '전라남도 순천시', '전라남도 순천시', '경기도 수원시', '경기도 수원시', '충청북도 괴산군', '경상남도 함양군', '경상남도 함양군', '경상남도 함양군', '경상남도 함양군', '강원도 춘천시', '강원도 춘천시', '강원도 춘천시', '강원도 춘천시', '강원도 춘천시', '강원도 춘천시', '강원도 춘천시', '강원도 춘천시', '강원도 춘천시', '충청남도 아산시', '충청남도 아산시', '충청남도 아산시'] 99

# %%
rev_dict1 = dict()
for v in all_data:
    if v[1] not in rev_dict1.keys():
        rev_dict1[v[1]] = {v[0]}
    else:
        rev_dict1[v[1]].add(v[0])
print(len(rev_dict1))
# Out:
# 1155

# %%
p_list=[]
for v in all_data:
    p_list.append(v[1])

p_set=set(p_list)
count_list=[]
for v in p_set:
    count_list.append((v, p_list.count(v)))
x = sorted(count_list, key= lambda x : x[1], reverse = True)
print(x[:])
# Out:
# [('고추', 540), ('대파', 348), ('상추', 289), ('배추', 249), ('고구마', 234), ('딸기', 224), ('감자', 219), ('포도', 217), ('복숭아', 207), ('감말랭이', 186), ('블루베리', 184), ('무', 179), ('쪽파', 150), ('부추', 150), ('양파', 148), ('오이', 136), ('토마토', 133), ('감', 131), ('시금치', 129), ('마늘', 119), ('가지', 119), ('사과', 99), ('열무', 96), ('대추', 89), ('표고버섯', 83), ('당근', 81), ('도라지', 66), ('호박', 65), ('생강', 65), ('양배추', 61), ('깻잎', 59), ('고사리', 59), ('콩', 56), ('아로니아', 55), ('땅콩', 55), ('배', 54), ('취나물', 52), ('고구마순', 50), ('쌀', 48), ('두릅', 45), ('자두', 45), ('갓', 44), ('아욱', 43), ('방울토마토', 43), ('옥수수', 43), ('단호박', 42), ('파', 41), ('머위', 40), ('서리태', 38), ('애호박', 38), ('아스파라거스', 37), ('호박잎', 35), ('물김', 34), ('무청시래기', 33), ('얼갈이배추', 32), ('고구마줄기', 31), ('수박', 31), ('냉이', 30), ('들깨', 30), ('알타리무', 30), ('돼지감자', 30), ('곶감', 29), ('매실', 28), ('복숭아 ', 27), ('밤', 27), ('쑥갓', 27), ('', 26), ('풋마늘', 23), ('참깨', 22), ('노각', 22), ('달래', 22), ('여주', 20), ('단감', 20), ('고들빼기', 18), ('참나물', 18), ('메론', 18), ('꽈리고추', 18), ('다래', 17), ('더덕', 17), ('느타리버섯', 16), ('미나리', 16), ('비트', 16), ('양상추', 16), ('치커리', 15), ('대추토마토', 15), ('살구', 15), ('호두', 15), ('벼', 14), ('완두콩', 14), ('강낭콩', 14), ('채소류', 14), ('고추 ', 14), ('팥', 14), ('마', 14), ('고구마 ', 14), ('표고', 13), ('파프리카', 13), ('모과', 13), ('포도 ', 13), ('꿀', 13), ('쑥', 13), ('꾸지뽕', 12), ('가공품', 12), ('시래기', 12), ('천년초', 12), ('청양고추', 12), ('오이고추', 12), ('늙은호박', 11), ('봄동', 11), ('쌈채', 11), ('오미자', 11), ('딸기 ', 11), ('눈개승마', 11), ('청경채', 11), ('찹쌀', 11), ('무화과', 11), ('무말랭이', 11), ('토란', 10), ('콜라비', 10), ('초롱무', 10), ('작두콩', 10), ('구기자', 10), ('엄나무순', 10), (' 방울토마토', 10), ('꿀류', 10), ('들깻잎', 10), ('블랙베리', 10), ('민들레', 10), ('연근', 9), ('버섯', 9), ('마늘쫑', 9), ('한라봉', 9), ('머윗대', 9), ('참', 9), ('수수', 9), ('플럼코트', 9), ('우엉', 9), ('대추 ', 9), ('새싹인삼', 8), ('산딸기 ', 8), ('곤드레', 8), ('산채류', 8), ('초석잠', 8), ('체리', 8), ('와송', 8), ('돌미나리', 8), ('은행', 8), ('땅두릅', 8), ('배추 ', 8), ('산딸기', 8), ('케일', 8), ('기획행사', 8), ('삼채', 8), ('개복숭아', 8), ('사과즙', 7), ('키위', 7), ('목이버섯', 7), ('허브', 7), ('감자 ', 7), ('완두', 7), ('망초대', 7), ('브로콜리', 7), ('대추방울토마토', 7), ('사과대추', 7), ('복분자', 7), ('오디', 7), ('미니파프리카', 7), ('복수박', 6), ('밀 ', 6), ('새싹삼', 6), ('찰벼', 6), ('호랑이콩', 6), ('콩나물', 6), ('미니사과', 6), ('토마토 ', 6), ('자두 ', 6), ('사과 ', 6), ('실파', 6), ('아로니아베리', 6), ('울금', 6), ('된장', 6), ('표고버섯 ', 6), ('샤인머스켓', 6), ('오가피순', 6), ('근대', 6), ('엇갈이배추', 5), ('고추장', 5), ('돗나물', 5), ('마늘 ', 5), ('꽃가루', 5), ('배 ', 5), ('어성초', 5), ('쥐눈이콩', 5), ('블랙커런트', 5), ('명이나물', 5), ('메리골드', 5), ('유정란', 5), ('수세미', 5), ('쌈채소', 5), ('홍고추', 5), ('애플수박', 5), ('토란줄기', 5), ('녹두', 5), ('대두', 5), ('새꼬막', 5), ('고수', 5), ('밤호박', 5), ('울타리콩', 5), ('동부', 5), ('양봉산물', 5), ('멜론', 5), ('풋고추', 5), ('호두 ', 4), ('멜라초', 4), ('밀', 4), ('조', 4), ('연잎', 4), ('목이', 4), ('고사리 ', 4), ('영지버섯', 4), ('인삼', 4), ('피망', 4), ('열매마', 4), ('곰취', 4), ('엉겅퀴', 4), ('비름나물', 4), ('황기', 4), ('백미', 4), ('귀리', 4), ('백태', 4), ('벌꿀', 4), ('바이오체리', 4), ('블루베리 ', 4), ('화분', 4), ('오미자즙', 4), ('상추 ', 4), ('아로니아 ', 4), ('노루궁뎅이버섯', 4), ('박나물', 4), ('방풍나물', 4), ('야콘', 4), ('돌배', 4), ('보리', 4), ('헛개나무', 4), ('노각오이', 4), ('양파 ', 4), ('감귤', 4), ('토란대', 4), ('마늘잎', 4), ('사과참', 3), ('쥬키니호박', 3), ('메밀순', 3), ('레드향', 3), ('감 ', 3), ('옻', 3), ('숙주나물', 3), ('중파', 3), ('콩나물콩', 3), ('쌈배추', 3), ('생채', 3), ('나물류', 3), ('아주까리잎', 3), ('가시오가피', 3), ('차류', 3), ('약초류', 3), ('노루궁뎅이', 3), ('꼬들빼기', 3), ('간장', 3), ('장류', 3), ('홑잎나물', 3), ('귤', 3), ('절임배추', 3), ('다래순', 3), ('들기름', 3), ('감자밭콩', 3), ('공심채', 3), ('옥수수 ', 3), ('계란', 3), ('고로쇠 수액', 3), ('고로쇠수액', 3), ('들깨 ', 3), ('얼갈이', 3), ('취', 3), ('옥수수쌀', 3), ('시금치 ', 3), ('대표품목 미설정 ', 3), ('산마늘', 3), ('아삭이고추', 3), ('참송이버섯', 3), ('누룽지', 3), ('무우', 3), ('샐러리', 3), ('말랭이', 3), ('체소류', 3), ('김부각', 3), ('다류', 3), ('꼬들베기', 3), ('보리 ', 3), ('비트잎', 3), ('직거래장터', 3), ('장아찌류', 3), ('원추리', 3), ('새싹보리', 3), ('양파즙', 3), ('고춧잎', 3), ('곡류', 3), ('유지류', 3), ('강황', 3), ('양송이', 3), ('솔순', 3), ('부추 ', 3), ('즙류', 3), ('산양삼', 2), ('아피오스', 2), ('참다래', 2), ('우유', 2), ('옻순', 2), ('흑임자', 2), ('느타리', 2), ('적상추', 2), ('건고추', 2), ('꾸지뽕나무', 2),  ...
