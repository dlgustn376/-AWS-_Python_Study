# %% [markdown]
# ## 전국푸드트럭허가구역 표준데이타
#
# - 전국 / 지자체 푸드트럭 허가구역 은 갯수
# - 전국 / 지자체별 푸드트럭 운영대수

# %%
import numpy as np
import pandas as pd

pd_data = pd.read_csv('전국푸드트럭허가구역표준데이터.csv', encoding='cp949')

# %%
for i in enumerate(pd_data.columns):
    print(i)
# Out:
# (0, '허가구역명')
# (1, '장소유형')
# (2, '시도명')
# (3, '시군구명')
# (4, '소재지도로명주소')
# (5, '소재지지번주소')
# (6, '위도')
# (7, '경도')
# (8, '푸드트럭운영대수')
# (9, '허가구역사용료')
# (10, '허가구역운영시작일자')
# (11, '허가구역운영종료일자')
# (12, '허가구역휴무일')
# (13, '허가구역평일운영시작시각')
# (14, '허가구역평일운영종료시각')
# (15, '허가구역주말운영시작시각')
# (16, '허가구역주말운영종료시각')
# (17, '1월운영시작시각')
# (18, '1월운영종료시각')
# (19, '2월운영시작시각')
# (20, '2월운영종료시각')
# (21, '3월운영시작시각')
# (22, '3월운영종료시각')
# (23, '4월운영시작시각')
# (24, '4월운영종료시각')
# (25, '5월운영시작시각')
# (26, '5월운영종료시각')
# (27, '6월운영시작시각')
# (28, '6월운영종료시각')
# (29, '7월운영시작시각')
# (30, '7월운영종료시각')
# (31, '8월운영시작시각')
# (32, '8월운영종료시각')
# (33, '9월운영시작시각')
# (34, '9월운영종료시각')
# (35, '10월운영시작시각')
# (36, '10월운영종료시각')
# (37, '11월운영시작시각')
# (38, '11월운영종료시각')
# (39, '12월운영시작시각')
# (40, '12월운영종료시각')
# (41, '판매제한품목')
# (42, '관리기관명')
# (43, '관리기관전화번호')
# (44, '데이터기준일자')
# (45, '제공기관코드')
# (46, '제공기관명')

# %%
national_site_count_data = pd_data.shape[0]
pd_data['시도명'].shape
# Out:
# (342,)

# %%
pd_data['푸드트럭운영대수'].sum()
# Out:
# 444.0

# %%
sub_data = pd_data[['시도명','푸드트럭운영대수']]
sub_data.groupby('시도명').sum()
# Out:
#          푸드트럭운영대수
# 시도명
# 강원도          25.0
# 경기도         136.0
# 경상남도         57.0
# 경상북도         17.0
# 광주광역시        14.0
# 대구광역시         4.0
# 대전광역시        12.0
# 부산광역시        17.0
# 서울특별시        35.0
# 울산광역시         1.0
# 인천광역시         9.0
# 전라남도         29.0
# 전라북도         10.0
# 제주특별자치도      41.0
# 충청남도         30.0
# 충청북도          7.0
