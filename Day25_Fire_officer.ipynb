# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

font_path = "C:\Windows\Fonts\HMKMRHD.TTF"
kfont = matplotlib.font_manager.FontProperties(fname=font_path).get_name()

matplotlib.rcParams['font.family'] = [kfont]

# %%
pd_data = pd.read_csv('소방공무원_시도별_2010-2021.csv', encoding='cp949')
filter1 = pd_data['행정구역별'] != '전국'
pd_data_f = pd_data[filter1]
print(pd_data_f.shape)
# Out:
# (202, 5)

# %%
print(pd_data_f.shape)
print(pd_data_f.dtypes)
# Out:
# (202, 5)
# 행정구역별                        object
# 시점                            int64
# 소방공무원 1인당 담당주민수<br>(A÷B)    float64
# 주민등록인구<br>(A)                 int64
# 소방공무원 수<br>(B)                int64
# dtype: object

# %%
sns.catplot(data = pd_data_f, x='시점', y='소방공무원 1인당 담당주민수<br>(A÷B)', kind='bar', col='행정구역별', col_wrap=3)

# %%
sns.catplot(data = pd_data_f, x='시점', y='소방공무원 수<br>(B)', kind='bar', col='행정구역별', col_wrap=3)

# %%
pd_data.to_csv('소방공무원_시도별_2010-2021_pass1.csv')
