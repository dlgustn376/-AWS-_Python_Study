# %% [markdown]
# ### 데이터 산업 현황 2015-2021
#
# * 데이터 산업별 시장규모 성장추이    --> line(ax.plot)
# * 2015,2021 데이터 산업별 구성비 비교 --> pie

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

font_path = "C:\Windows\Fonts\HMKMRHD.TTF"
kfont = matplotlib.font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rcParams['font.family'] = [kfont]

pd_data = pd.read_csv('데이터산업_시장규모_2015-2021.csv', encoding='cp949')
print(pd_data)
# Out:
#      시점  데이터 처리 및 관리 솔루션 개발·공급업  데이터 구축 및 컨설팅 서비스업  데이터 판매 및 제공 서비스업
# 0  2015                   14124              55280             64151
# 1  2016                   15720              55850             65977
# 2  2017                   16457              58894             68179
# 3  2018                   18617              61290             75778
# 4  2019                   20805              65412             82364
# 5  2020                   25133              76999             97891
# 6  2021                   30566              86335            114071

# %%
for e in pd_data['시점']:
    print(e)
# Out:
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021

# %%
fig = plt.figure()
a = fig.add_subplot(2,1,1)
b = fig.add_subplot(2,2,3)
c = fig.add_subplot(2,2,4)

col_names = pd_data.columns[-3:]

for e in pd_data['시점']:
    filter1 = pd_data['시점']==e
    xs = pd_data.loc[filter1,'시점']
    ys = pd_data.loc[filter1, col_names]
    
    a.plot(xs.astype('str'), ys.iloc[:,0] , 'gv:', linewidth=2)
    a.plot(xs.astype('str'), ys.iloc[:,1] , 'ro--', linewidth=2)
    a.plot(xs.astype('str'), ys.iloc[:,2] , 'b>-', linewidth=2)

b.pie(pd_data.iloc[0,1:])
c.pie(pd_data.iloc[6,1:])
# Out:
# ([<matplotlib.patches.Wedge at 0x1c4eb282e90>,
# ...
#  [Text(1.0062963527639606, 0.4442607909932528, ''),
#   Text(-0.4635448352231071, 0.9975601163528857, ''),
#   Text(0.021169715733660534, -1.099796273468753, '')])

# %%
for i, n in enumerate(pd_data['데이터직무별(1)'].unique()):
    filter1 = pd_data['데이터직무별(1)'] ==n
    ax = axes[i//4, i%4]
    xs = pd_data.loc[filter1, '시점']
    ys = pd_data.loc[filter1, col_names]
    ax.set_title(n)
#     ax.plot(xs.astype('str'),ys.iloc[:,0] , 'go--')
    ax.plot(xs.astype('str'),ys.iloc[:,0] , 'gv--')
    ax.plot(xs.astype('str'),ys.iloc[:,1] , 'ro--')
